# %%
# %%time

from pyspark.sql import SparkSession
from matplotlib import pyplot as plt
import time
import numpy

spark = SparkSession \
 .builder \
 .master("local[*]") \
 .appName("PySpark Netflow Benchmark code") \
 .config("spark.jars.packages","ch.cern.sparkmeasure:spark-measure_2.11:0.13")  \
 .getOrCreate()
# Out:
# CPU times: user 1.25 s, sys: 1.31 s, total: 2.56 s
# Wall time: 4.55 s

# %%
# %%time
# load CSV into Spark
netflow_df = spark.read.format('com.databricks.spark.csv').options(header='true', inferschema='true').load('./data/nf-chunk2.csv')
# Out:
# CPU times: user 10.7 ms, sys: 12.8 ms, total: 23.5 ms
# Wall time: 54.7 s

# %%
# %%time
# create table for querying
netflow_df.createOrReplaceTempView('netflow')
# Out:
# CPU times: user 1.51 ms, sys: 1.22 ms, total: 2.73 ms
# Wall time: 41.8 ms

# %%
result = spark.sql('''SELECT * FROM netflow a''')
print(result);
# Out:
# DataFrame[TimeSeconds: double, parsedDate: timestamp, dateTimeStr: double, ipLayerProtocol: int, ipLayerProtocolCode: string, firstSeenSrcIp: string, firstSeenDestIp: string, firstSeenSrcPort: int, firstSeenDestPort: int, moreFragments: int, contFragments: int, durationSeconds: int, firstSeenSrcPayloadBytes: int, firstSeenDestPayloadBytes: int, firstSeenSrcTotalBytes: int, firstSeenDestTotalBytes: int, firstSeenSrcPacketCount: int, firstSeenDestPacketCount: int, recordForceOut: int]

# %%
# %%time

num_runs = 10
queryId = 'TEST_01'
print(queryId)

# make a query
queries = []
queries.append('''SELECT a.firstSeenSrcIP as source FROM netflow a''')
queries.append('''SELECT count(a.firstSeenDestPort) as targetPorts FROM netflow a''')
queries.append('''SELECT SUM(a.firstSeenSrcTotalBytes) as bytesOut FROM netflow a''')
queries.append('''SELECT AVG(a.firstSeenDestTotalBytes) as bytesIn FROM netflow a''')
queries.append('''SELECT DISTINCT(a.durationSeconds) as durationSeconds FROM netflow a''')
queries.append('''SELECT MIN(parsedDate) as firstFlowDate FROM netflow a''')
queries.append('''SELECT MAX(parsedDate) as lastFlowDate FROM netflow a''')
queries.append('''SELECT COUNT(*) as attemptCount FROM netflow a''')

all_times=[]
for query in queries:
    times=[]
    result0 = ""
    print("\nquery:", query)
    for i in range(0,num_runs):
       t0 = time.time()
       result = spark.sql(query)
       t2 = time.time()
       times.append(t2 - t0)
       result0 = result
       del result
       time.sleep(1)
    print(result0)
    all_times.append(times)
    for j in range(0,num_runs):
       print("times[%d]:" %j + str(times[j]))
# Out:
# TEST_01
#
# query: SELECT a.firstSeenSrcIP as source FROM netflow a
# DataFrame[source: string]
# times[0]:0.18257808685302734
# times[1]:0.008485794067382812
# times[2]:0.013235807418823242
# times[3]:0.00836801528930664
# times[4]:0.008410930633544922
# times[5]:0.008655548095703125
# times[6]:0.008283138275146484
# times[7]:0.008509635925292969
# times[8]:0.007044315338134766
# times[9]:0.0077571868896484375
#
# query: SELECT count(a.firstSeenDestPort) as targetPorts FROM netflow a
# DataFrame[targetPorts: bigint]
# times[0]:0.04113149642944336
# times[1]:0.013326644897460938
# times[2]:0.01275944709777832
# times[3]:0.01970195770263672
# times[4]:0.012926340103149414
# times[5]:0.010816097259521484
# times[6]:0.01409769058227539
# times[7]:0.013797283172607422
# times[8]:0.009499311447143555
# times[9]:0.021020174026489258
#
# query: SELECT SUM(a.firstSeenSrcTotalBytes) as bytesOut FROM netflow a
# DataFrame[bytesOut: bigint]
# times[0]:0.020571231842041016
# times[1]:0.011971473693847656
# times[2]:0.011891365051269531
# times[3]:0.0117034912109375
# times[4]:0.013794422149658203
# times[5]:0.010701656341552734
# times[6]:0.010343551635742188
# times[7]:0.010530948638916016
# times[8]:0.010092973709106445
# times[9]:0.008973121643066406
#
# query: SELECT AVG(a.firstSeenDestTotalBytes) as bytesIn FROM netflow a
# DataFrame[bytesIn: double]
# times[0]:0.00980830192565918
# times[1]:0.009486675262451172
# times[2]:0.01222681999206543
# times[3]:0.009912729263305664
# times[4]:0.008863210678100586
# times[5]:0.009412765502929688
# times[6]:0.00874185562133789
# times[7]:0.008175373077392578
# times[8]:0.011011600494384766
# times[9]:0.008925914764404297
#
# query: SELECT DISTINCT(a.durationSeconds) as durationSeconds FROM netflow a
# DataFrame[durationSeconds: int]
# times[0]:0.01764965057373047
# times[1]:0.006739616394042969
# times[2]:0.006911277770996094
# times[3]:0.007348775863647461
# times[4]:0.006472349166870117
# times[5]:0.006400585174560547
# times[6]:0.006684303283691406
# times[7]:0.00914907455444336
# times[8]:0.0059146881103515625
# times[9]:0.006477832794189453
#
# query: SELECT MIN(parsedDate) as firstFlowDate FROM netflow a
# DataFrame[firstFlowDate: timestamp]
# times[0]:0.010348796844482422
# times[1]:0.005666494369506836
# times[2]:0.006123542785644531
# times[3]:0.005655527114868164
# times[4]:0.005769252777099609
# times[5]:0.006281852722167969
# times[6]:0.006360054016113281
# times[7]:0.00606226921081543
# times[8]:0.0057451725006103516
# times[9]:0.005524158477783203
#
# query: SELECT MAX(parsedDate) as lastFlowDate FROM netflow a
# DataFrame[lastFlowDate: timestamp]
# times[0]:0.0050542354583740234
# times[1]:0.005049228668212891
# times[2]:0.006440162658691406
# times[3]:0.006432294845581055
# times[4]:0.006203413009643555
# times[5]:0.006409883499145508
# times[6]:0.004984378814697266
# times[7]:0.006932973861694336
# times[8]:0.006071567535400391
# times[9]:0.005418062210083008
#
# query: SELECT COUNT(*) as attemptCount FROM netflow a
# DataFrame[attemptCount: bigint]
# times[0]:0.006803274154663086
# times[1]:0.00485682487487793
# times[2]:0.005147695541381836
# times[3]:0.010740995407104492
# times[4]:0.004365205764770508
# times[5]:0.008349180221557617
# times[6]:0.004698991775512695
# times[7]:0.004914045333862305
# times[8]:0.0054891109466552734
# times[9]:0.0057163238525390625
# CPU times: user 77.2 ms, sys: 17.9 ms, total: 95.1 ms
# Wall time: 1min 21s

# %%
num_runs = 1
query = '''
        SELECT
            a.firstSeenSrcIp as source,
            a.firstSeenDestIp as destination,
            count(a.firstSeenDestPort) as targetPorts,
            SUM(a.firstSeenSrcTotalBytes) as bytesOut,
            AVG(a.firstSeenDestTotalBytes) as bytesIn,
            SUM(a.durationSeconds) as durationSeconds,
            MIN(parsedDate) as firstFlowDate,
            MAX(parsedDate) as lastFlowDate,
            COUNT(*) as attemptCount
        FROM
            netflow a
        GROUP BY
            a.firstSeenSrcIp,
            a.firstSeenDestIp
            '''

all_times=[]
times=[]
result0 = ""
results = []
print("\nquery:", query)
for i in range(0,num_runs):
   t0 = time.time()
   # %prun result = spark.sql(query)
   t2 = time.time()
   times.append(t2 - t0)
   results.append(result)
   result0 = result
   del result
   print("trial ", i + 1, " done")
   time.sleep(1)
result0.show()
all_times.append(times)
for j in range(0,num_runs):
   print("times[%d]:" %j + str(times[j]))
# Out:
# query:
#         SELECT
#             a.firstSeenSrcIp as source,
#             a.firstSeenDestIp as destination,
#             count(a.firstSeenDestPort) as targetPorts,
#             SUM(a.firstSeenSrcTotalBytes) as bytesOut,
#             AVG(a.firstSeenDestTotalBytes) as bytesIn,
#             SUM(a.durationSeconds) as durationSeconds,
#             MIN(parsedDate) as firstFlowDate,
#             MAX(parsedDate) as lastFlowDate,
#             COUNT(*) as attemptCount
#         FROM
#             netflow a
#         GROUP BY
#             a.firstSeenSrcIp,
#             a.firstSeenDestIp
#
#  trial  1  done
# +------------+---------------+-----------+--------+-----------------+---------------+-------------------+-------------------+------------+
# |      source|    destination|targetPorts|bytesOut|          bytesIn|durationSeconds|      firstFlowDate|       lastFlowDate|attemptCount|
# +------------+---------------+-----------+--------+-----------------+---------------+-------------------+-------------------+------------+
# | 172.10.1.13|239.255.255.250|         15|    2975|              0.0|              6|2013-04-03 06:36:19|2013-04-03 06:36:27|          15|
# |172.30.1.204|239.255.255.250|          8|    1750|              0.0|              6|2013-04-03 06:36:13|2013-04-03 06:36:20|           8|
# | 172.30.2.86|      172.0.0.1|          1|     540|              0.0|              2|2013-04-03 06:36:09|2013-04-03 06:36:09|           1|
# |172.30.1.246|      172.0.0.1|         29|    2610|             90.0|              0|2013-04-03 00:26:46|2013-04-03 23:06:00|          29|
# | 172.30.1.51|239.255.255.250|         16|    3850|              0.0|             18|2013-04-03 06:35:22|2013-04-03 06:44:08|          16|
# | 172.10.1.35|      172.0.0.1|          1|     270|              0.0|              0|2013-04-03 06:36:21|2013-04-03 06:36:21|           1|
# | 172.20.1.91|239.255.255.250|         19|    3675|              0.0|              6|2013-04-03 06:36:50|2013-04-03 06:36:59|          19|
# |172.20.1.249|239.255.255.250|          2|     700|              0.0|              6|2013-04-03 06:37:17|2013-04-03 06:37:23|           2|
# |172.10.1.232|      172.0.0.1|         30|    3060|            102.0|             48|2013-04-03 01:31:31|2013-04-03 22:53:36|          30|
# |172.10.1.238|239.255.255.250|          2|     700|              0.0|              6|2013-04-03 06:36:44|2013-04-03 06:36:51|           2|
# |172.10.2.137|      172.0.0.1|         28|    2520|80.35714285714286|              0|2013-04-03 01:10:48|2013-04-03 23:15:00|          28|
# |172.30.1.131|       10.0.0.5|         83|   37545|630.6987951807229|              2|2013-04-03 06:48:00|2013-04-03 12:01:20|          83|
# |172.30.1.200|       10.0.0.6|         70|   31548|628.9142857142857|              2|2013-04-03 06:48:03|2013-04-03 12:02:30|          70|
# |172.30.1.115|      10.0.0.14|         71|   32126|625.7183098591549|              2|2013-04-03 06:48:05|2013-04-03 11:49:25|          71|
# |172.30.2.145|       10.0.0.8|         61|   26564|608.4918032786885|              5|2013-04-03 06:48:09|2013-04-03 12:12:36|          61|
# |172.30.1.112|       10.0.0.5|         72|   32562|           631.25|             19|2013-04-03 06:48:09|2013-04-03 11:44:06|          72|
# |172.30.1.239|      10.0.0.11|        120|   53980|623.4166666666666|              0|2013-04-03 06:49:20|2013-04-03 14:51:26|         120|
# |172.20.1.246|      10.0.0.13|        111|   50348|615.3423423423424|             58|2013-04-03 06:49:22|2013-04-03 15:03:48|         111|
# |172.30.2.146|      10.0.0.10|         68|   30480|622.8970588235294|              7|2013-04-03 06:48:46|2013-04-03 12:06:50|          68|
# |172.10.1.151|      10.1.0.76|         64|   29414|        632.15625|             17|2013-04-03 06:48:37|2013-04-03 14:59:43|          64|
# +------------+---------------+-----------+--------+-----------------+---------------+-------------------+-------------------+------------+
# only showing top 20 rows
#
# times[0]:0.07673931121826172
#          112 function calls in 0.068 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.068    0.068    0.068    0.068 {method 'recv_into' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 finalizer.py:35(add_finalizer)
#         1    0.000    0.000    0.068    0.068 java_gateway.py:1130(send_command)
#         1    0.000    0.000    0.068    0.068 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 java_gateway.py:1269(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'sendall' of '_socket.socket' objects}
#         1    0.000    0.000    0.068    0.068 session.py:755(sql)
#         1    0.000    0.000    0.068    0.068 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.068    0.068 java_gateway.py:1247(__call__)
#         1    0.000    0.000    0.000    0.000 java_gateway.py:1192(_get_args)
#         4    0.000    0.000    0.000    0.000 protocol.py:214(smart_decode)
#         1    0.000    0.000    0.000    0.000 dataframe.py:77(__init__)
#         1    0.000    0.000    0.068    0.068 java_gateway.py:962(send_command)
#         9    0.000    0.000    0.000    0.000 inspect.py:1524(_static_getmro)
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.068    0.068 socket.py:575(readinto)
#         5    0.000    0.000    0.000    0.000 inspect.py:1552(_shadowed_dict)
#         1    0.000    0.000    0.000    0.000 protocol.py:263(get_command_part)
#         2    0.000    0.000    0.000    0.000 inspect.py:1566(getattr_static)
#         1    0.000    0.000    0.000    0.000 java_gateway.py:1210(_build_args)
#         1    0.000    0.000    0.000    0.000 protocol.py:305(get_return_value)
#         1    0.000    0.000    0.068    0.068 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 java_gateway.py:940(_give_back_connection)
#         2    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:1527(_check_instance)
#         1    0.000    0.000    0.000    0.000 java_gateway.py:2463(<lambda>)
#         1    0.000    0.000    0.000    0.000 utils.py:61(deco)
#         1    0.000    0.000    0.000    0.000 protocol.py:177(escape_new_line)
#         2    0.000    0.000    0.000    0.000 inspect.py:1545(_is_type)
#         2    0.000    0.000    0.000    0.000 __init__.py:1356(debug)
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 java_collections.py:491(can_convert)
#         1    0.000    0.000    0.000    0.000 protocol.py:380(is_fatal_error)
#         2    0.000    0.000    0.000    0.000 inspect.py:1536(_check_class)
#         1    0.000    0.000    0.000    0.000 java_collections.py:506(can_convert)
#         1    0.000    0.000    0.000    0.000 java_gateway.py:925(_get_connection)
#         2    0.000    0.000    0.000    0.000 compat.py:118(hasattr2)
#         2    0.000    0.000    0.000    0.000 __init__.py:1614(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 java_gateway.py:1218(<listcomp>)
#         1    0.000    0.000    0.000    0.000 java_gateway.py:1312(__getattr__)
#         1    0.000    0.000    0.000    0.000 protocol.py:373(is_error)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method '_checkReadable' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 types.py:1562(can_convert)
#         1    0.000    0.000    0.000    0.000 java_collections.py:479(can_convert)
#         1    0.000    0.000    0.000    0.000 socket.py:614(readable)
#         1    0.000    0.000    0.000    0.000 abc.py:137(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method '_checkClosed' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 types.py:1571(can_convert)
#         2    0.000    0.000    0.000    0.000 compat.py:100(isbytearray)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 compat.py:97(ispython3bytestr)

# %%
for times in (all_times):
    sum = 0.0
    for time_result in (times):
        sum += time_result

    print("총합: " + str(sum))
    print("평균: " + str(numpy.mean(times, keepdims=False)))
    print("분산: " + str(numpy.var(times)))
    print("표준편차: " + str(numpy.std(times)))
    print("\n")
# Out:
# 총합: 0.07673931121826172
# 평균: 0.07673931121826172
# 분산: 0.0
# 표준편차: 0.0

# %%
# how's it look?
# df_result = cudf.DataFrame(result0)
# results[0].to_csv("result_pyspark.csv", index=False)
results[0].coalesce(1).write.format("com.databricks.spark.csv").save("result_pyspark.csv")
