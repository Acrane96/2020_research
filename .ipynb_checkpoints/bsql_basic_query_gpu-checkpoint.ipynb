# %%
from blazingsql import BlazingContext
from matplotlib import pyplot as plt
import cudf
import time
import numpy

bc_cudf = BlazingContext(pool=True)
bc_cudf.s3('blazingsql-colab', bucket_name='blazingsql-colab')
# Out:
# BlazingContext ready
# (True,
#  '',
#  OrderedDict([('type', 's3'),
#               ('bucket_name', 'blazingsql-colab'),
#               ('access_key_id', ''),
#               ('secret_key', ''),
#               ('session_token', ''),
#               ('encryption_type', <S3EncryptionType.NONE: 1>),
#               ('kms_key_amazon_resource_name', '')]))

# %%
# %%time
# Load CSVs into GPU DataFrames with cudf (GDF)
netflow_gdf_cudf = cudf.read_csv('./data/nf-chunk2.csv')
# Out:
# /usr/local/envs/bsql/lib/python3.7/site-packages/fsspec/implementations/local.py:33: FutureWarning: The default value of auto_mkdir=True has been deprecated and will be changed to auto_mkdir=False by default in a future release.
#   FutureWarning,
# CPU times: user 3.66 s, sys: 793 ms, total: 4.46 s
# Wall time: 4.44 s

# %%
# %%time
# Create BlazingSQL table from GDF
# col_names = ['TimeSeconds','parsedDate','dateTimeStr','ipLayerProtocol','ipLayerProtocolCode','firstSeenSrcIp','firstSeenDestIp','firstSeenSrcPort','firstSeenDestPort','moreFragments','contFragments','durationSeconds','firstSeenSrcPayloadBytes','firstSeenDestPayloadBytes','firstSeenSrcTotalBytes','firstSeenDestTotalBytes','firstSeenSrcPacketCount','firstSeenDestPacketCount','recordForceOut']
# bc_cudf.create_table('netflow', '/blazingsql/2020_research/data/final.csv', delimiter='|', names=col_names)

bc_cudf.create_table('netflow', netflow_gdf_cudf)
# Out:
# CPU times: user 13.3 ms, sys: 417 µs, total: 13.7 ms
# Wall time: 7.51 ms

# %%
netflow_gdf_cudf.head()
# Out:
#     TimeSeconds           parsedDate   dateTimeStr  ipLayerProtocol  \
# 0  1.364948e+09  2013-04-03 00:11:50  2.013040e+13                6
# 1  1.364948e+09  2013-04-03 00:11:53  2.013040e+13                6
# 2  1.364948e+09  2013-04-03 00:11:54  2.013040e+13               17
# 3  1.364948e+09  2013-04-03 00:11:57  2.013040e+13                6
# 4  1.364948e+09  2013-04-03 00:12:00  2.013040e+13                6
#
#   ipLayerProtocolCode firstSeenSrcIp  firstSeenDestIp  firstSeenSrcPort  \
# 0                 TCP    10.38.37.13       172.20.0.3             42559
# 1                 TCP    10.13.77.49       172.30.0.4             42566
# 2                 UDP    172.10.0.40  172.255.255.255               138
# 3                 TCP  10.156.215.83       172.10.0.7             42593
# 4                 TCP  10.170.32.110       172.20.0.4             42612
#
#    firstSeenDestPort  moreFragments  contFragments  durationSeconds  \
# 0                 25              0              0               10
# 1                 25              0              0                9
# 2                138              0              0                0
# 3                 80              0              0                0
# 4                 80              0              0                3
#
#    firstSeenSrcPayloadBytes  firstSeenDestPayloadBytes  \
# 0                        36                        125
# 1                         0                          0
# 2                       201                          0
# 3                       170                        336
# 4                      1870                      79850
#
#    firstSeenSrcTotalBytes  firstSeenDestTotalBytes  firstSeenSrcPacketCount  \
# 0                     422                      403                        7
# 1                     186                        0                        3
# 2                     243                        0                        1
# 3                     448                      506                        5
# 4                    5730                    84250                       70
#
#    firstSeenDestPacketCount  recordForceOut
# 0                         5               0
# 1                         0               0
# 2                         0               0
# 3                         3               0
# 4                        80               0

# %%
# %%time
num_runs = 1

# make a query
queries = []
queries.append('''SELECT a.firstSeenSrcIP as source FROM netflow a''')
queries.append('''SELECT count(a.firstSeenDestPort) as targetPorts FROM netflow a''')
# queries.append('''SELECT SUM(a.firstSeenSrcTotalBytes) as bytesOut FROM netflow a''')
# queries.append('''SELECT AVG(a.firstSeenDestTotalBytes) as bytesIn FROM netflow a''')
# queries.append('''SELECT DISTINCT(a.durationSeconds) as durationSeconds FROM netflow a''')
queries.append('''SELECT MIN(parsedDate) as firstFlowDate FROM netflow a''')
queries.append('''SELECT MAX(parsedDate) as lastFlowDate FROM netflow a''')
queries.append('''SELECT COUNT(*) as attemptCount FROM netflow a''')
queries.append('''SELECT a.firstSeenSrcTotalBytes, a.firstSeenDestTotalBytes FROM netflow a ORDER BY a.firstSeenSrcTotalBytes''')
# queries.append('''SELECT netflow a.firstSeenSrcPacketCount, netflow_B a.firstSeenSrcPacketCount, netflow_B a.firstSeenDestPacketCount 
#                FROM netflow a 
#                INNER JOIN netflow_B a
#                ON (netflow a.firstSeenSrcPacketCount = netflow_B a.recordForceOut)''')

all_times=[]
for query in queries:
    times=[]
    result0 = ""
    print("\nquery:", query)
    for i in range(0,num_runs):
        print("start")
        t0 = time.time()
        result = bc_cudf.sql(query)
        t2 = time.time()
        times.append(t2 - t0)
        # result0 = result
        del result
        time.sleep(10)
        print(i+1, "query done")
    # print(result0)
    all_times.append(times)
    for j in range(0,num_runs):
        print("times[%d]:" %j + str(times[j]))
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/envs/bsql/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-6-a88d7069a12a>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', 'num_runs = 1\n\n# make a query\nqueries = []\nqueries.append(\'\'\'SELECT a.firstSeenSrcIP as source FROM netflow a\'\'\')\nqueries.append(\'\'\'SELECT count(a.firstSeenDestPort) as targetPorts FROM netflow a\'\'\')\n# queries.append(\'\'\'SELECT SUM(a.firstSeenSrcTotalBytes) as bytesOut FROM netflow a\'\'\')\n# queries.append(\'\'\'SELECT AVG(a.firstSeenDestTotalBytes) as bytesIn FROM netflow a\'\'\')\n# queries.append(\'\'\'SELECT DISTINCT(a.durationSeconds) as durationSeconds FROM netflow a\'\'\')\nqueries.append(\'\'\'SELECT MIN(parsedDate) as firstFlowDate FROM netflow a\'\'\')\nqueries.append(\'\'\'SELECT MAX(parsedDate) as lastFlowDate FROM netflow a\'\'\')\nqueries.append(\'\'\'SELECT COUNT(*) as attemptCount FROM netflow a\'\'\')\nqueries.append(\'\'\'SELECT a.firstSeenSrcTotalBytes, a.firstSeenDestTotalBytes FROM netflow a ORDER BY a.firstSeenSrcTotalBytes\'\'\')\n# queries.append(\'\'\'SELECT netflow a.firstSeenSrcPacketCount, netflow_B a.firstSeenSrcPacketCount, netflow_B a.firstSeenDestPacketCount \n#                FROM netflow a \n#                INNER JOIN netflow_B a\n#                ON (netflow a.firstSeenSrcPacketCount = netflow_B a.recordForceOut)\'\'\')\n\nall_times=[]\nfor query in queries:\n    times=[]\n    result0 = ""\n    print("\\nquery:", query)\n    for i in range(0,num_runs):\n        print("start")\n        t0 = time.time()\n        result = bc_cudf.sql(query)??\n        t2 = time.time()\n        times.append(t2 - t0)\n        # result0 = result\n        del result\n        time.sleep(10)\n        print(i+1, "query done")\n    # print(result0)\n    all_times.append(times)\n    for j in range(0,num_runs):\n        print("times[%d]:" %j + str(times[j]))\n')
#
#   File "/usr/local/envs/bsql/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2362, in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File "<decorator-gen-61>", line 2, in time
#
#   File "/usr/local/envs/bsql/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "/usr/local/envs/bsql/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1268, in time
#     expr_ast = self.shell.compile.ast_parse(expr)
#
#   File "/usr/local/envs/bsql/lib/python3.7/site-packages/IPython/core/compilerop.py", line 101, in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File "<unknown>", line 27
#     result = bc_cudf.sql(query)??
#                                ^
# SyntaxError: invalid syntax

# %%
num_runs = 1
query = '''
        SELECT
            a.firstSeenSrcIp as source,
            a.firstSeenDestIp as destination,
            count(a.firstSeenDestPort) as targetPorts,
            SUM(a.firstSeenSrcTotalBytes) as bytesOut,
            AVG(a.firstSeenDestTotalBytes) as bytesIn,
            SUM(a.durationSeconds) as durationSeconds,
            MIN(parsedDate) as firstFlowDate,
            MAX(parsedDate) as lastFlowDate,
            COUNT(*) as attemptCount
        FROM
            netflow a
        GROUP BY
            a.firstSeenSrcIp,
            a.firstSeenDestIp
            '''

all_times=[]
times=[]
results = []
print("\nquery:", query)
for i in range(0,num_runs):
   t0 = time.time()
   # %prun result = bc_cudf.sql(query)
   t2 = time.time()
   times.append(t2 - t0)
   results.append(result)
   result0 = result
   del result
   print("trial ", i + 1, " done")
   time.sleep(1)
print(result0)
all_times.append(times)
for j in range(0,num_runs):
   print("times[%d]:" %j + str(times[j]))
# Out:
# query:
#         SELECT
#             a.firstSeenSrcIp as source,
#             a.firstSeenDestIp as destination,
#             count(a.firstSeenDestPort) as targetPorts,
#             SUM(a.firstSeenSrcTotalBytes) as bytesOut,
#             AVG(a.firstSeenDestTotalBytes) as bytesIn,
#             SUM(a.durationSeconds) as durationSeconds,
#             MIN(parsedDate) as firstFlowDate,
#             MAX(parsedDate) as lastFlowDate,
#             COUNT(*) as attemptCount
#         FROM
#             netflow a
#         GROUP BY
#             a.firstSeenSrcIp,
#             a.firstSeenDestIp
#
#  trial  1  done
#              source      destination  targetPorts  bytesOut  bytesIn  \
# 0        172.10.0.6      172.30.2.78           14      1036        0
# 1       172.30.1.91        10.0.0.10           72     32580      624
# 2         10.0.0.12     172.20.2.108            1       571      108
# 3       172.30.1.60        10.0.0.13           74     32980      615
# 4          10.0.0.6      172.30.1.54            1       632      391
# ...             ...              ...          ...       ...      ...
# 18876   172.10.1.92  239.255.255.250            1       525        0
# 18877      10.0.0.8     172.10.1.224            1       632      391
# 18878  172.30.2.138        10.0.0.14           87     37288      585
# 18879     10.0.0.13      172.30.1.84            2      1266      392
# 18880  172.10.2.108        10.0.0.10           98     42660      627
#
#        durationSeconds        firstFlowDate         lastFlowDate  attemptCount
# 0                    0  2013-04-03 13:12:39  2013-04-03 23:16:30            14
# 1                  131  2013-04-03 06:48:28  2013-04-03 12:00:46            72
# 2                    0  2013-04-03 10:06:19  2013-04-03 10:06:19             1
# 3                    4  2013-04-03 06:48:08  2013-04-03 12:11:09            74
# 4                    0  2013-04-03 10:27:09  2013-04-03 10:27:09             1
# ...                ...                  ...                  ...           ...
# 18876                6  2013-04-03 06:36:27  2013-04-03 06:36:27             1
# 18877                0  2013-04-03 10:12:34  2013-04-03 10:12:34             1
# 18878              129  2013-04-03 06:50:42  2013-04-03 12:12:37            87
# 18879                0  2013-04-03 09:59:50  2013-04-03 10:01:46             2
# 18880               12  2013-04-03 06:50:21  2013-04-03 14:49:17            98
#
# [18881 rows x 9 columns]
# times[0]:0.6821136474609375
#          2723 function calls (2722 primitive calls) in 0.679 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.616    0.616    0.616    0.616 context.py:906(explain)
#         1    0.060    0.060    0.062    0.062 {built-in method cio.runQueryCaller}
#         1    0.001    0.001    0.001    0.001 {built-in method cio.getTableScanInfoCaller}
#        79    0.000    0.000    0.001    0.000 dtypes.py:79(is_categorical_dtype)
#       868    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       358    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#       946    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        17    0.000    0.000    0.001    0.000 column.py:963(build_column)
#         1    0.000    0.000    0.679    0.679 context.py:1374(sql)
#        96    0.000    0.000    0.000    0.000 common.py:2020(pandas_dtype)
#        17    0.000    0.000    0.000    0.000 column.py:42(__init__)
#        17    0.000    0.000    0.000    0.000 buffer.py:135(_buffer_data_from_array_interface)
#         1    0.000    0.000    0.679    0.679 {built-in method builtins.exec}
#        13    0.000    0.000    0.000    0.000 numerical.py:21(__init__)
#        17    0.000    0.000    0.000    0.000 buffer.py:87(_init_from_array_like)
#        22    0.000    0.000    0.000    0.000 _collections_abc.py:760(__iter__)
#         4    0.000    0.000    0.000    0.000 string.py:1885(__init__)
#         9    0.000    0.000    0.000    0.000 utils.py:351(__setitem__)
#         1    0.000    0.000    0.000    0.000 dataframe.py:170(__init__)
#        17    0.000    0.000    0.000    0.000 buffer.py:12(__init__)
#         9    0.000    0.000    0.000    0.000 column.py:1046(as_column)
#         2    0.000    0.000    0.000    0.000 index.py:1007(as_index)
#        23    0.000    0.000    0.000    0.000 column_accessor.py:45(__getitem__)
#         9    0.000    0.000    0.000    0.000 utils.py:339(__setitem__)
#        54    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       5/4    0.000    0.000    0.000    0.000 dataframe.py:414(__getattr__)
#         2    0.000    0.000    0.000    0.000 column_accessor.py:16(__init__)
#         1    0.000    0.000    0.679    0.679 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 random.py:224(_randbelow)
#         4    0.000    0.000    0.000    0.000 string.py:1965(children)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 string.py:1948(set_base_mask)
#        17    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#         4    0.000    0.000    0.000    0.000 dataframe.py:387(__setattr__)
#         4    0.000    0.000    0.000    0.000 string.py:1956(set_base_children)
#         1    0.000    0.000    0.000    0.000 column_accessor.py:92(nrows)
#         1    0.000    0.000    0.000    0.000 context.py:244(modifyAlgebraForDataframesWithOnlyWantedColumns)
#         1    0.000    0.000    0.000    0.000 random.py:174(randrange)
#         1    0.000    0.000    0.000    0.000 random.py:218(randint)
#         2    0.000    0.000    0.000    0.000 abc.py:137(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 index.py:1057(_setdefault_name)
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:680(values)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 index.py:477(__init__)
#         4    0.000    0.000    0.000    0.000 {function StringColumn.set_base_children at 0x7f92d4c79680}
#         2    0.000    0.000    0.000    0.000 column_accessor.py:42(__iter__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:664(__contains__)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 index.py:539(copy)
#         4    0.000    0.000    0.000    0.000 string.py:1939(set_base_data)
#        12    0.000    0.000    0.000    0.000 string.py:2040(__len__)
#         4    0.000    0.000    0.000    0.000 {function StringColumn.set_base_data at 0x7f92d4c79560}
#         4    0.000    0.000    0.000    0.000 {function StringColumn.set_base_mask at 0x7f92d4c795f0}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         8    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 index.py:316(rename)
#         1    0.000    0.000    0.000    0.000 index.py:501(name)
#         5    0.000    0.000    0.000    0.000 column.py:124(__len__)
#         1    0.000    0.000    0.000    0.000 context.py:1429(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 index.py:497(name)

# %%
sums = []
# for (times, query) in (all_times, queries):
for times in all_times:
    sum = 0.0
    for time_result in (times):
        sum += time_result
    print("query: " + query)
    print("총합: " + str(sum))
    print("평균: " + str(numpy.mean(times)))
    print("분산: " + str(numpy.var(times)))
    print("표준편차: " + str(numpy.std(times)))
    print("\n")
# Out:
# query:
#         SELECT
#             a.firstSeenSrcIp as source,
#             a.firstSeenDestIp as destination,
#             count(a.firstSeenDestPort) as targetPorts,
#             SUM(a.firstSeenSrcTotalBytes) as bytesOut,
#             AVG(a.firstSeenDestTotalBytes) as bytesIn,
#             SUM(a.durationSeconds) as durationSeconds,
#             MIN(parsedDate) as firstFlowDate,
#             MAX(parsedDate) as lastFlowDate,
#             COUNT(*) as attemptCount
#         FROM
#             netflow a
#         GROUP BY
#             a.firstSeenSrcIp,
#             a.firstSeenDestIp
#
# 총합: 0.9873917102813721
# 평균: 0.9873917102813721
# 분산: 0.0
# 표준편차: 0.0

# %%
gdf

# %%
# how's it look?
# df_result = cudf.DataFrame(results)
results[0].to_csv("result.csv", index=False)
