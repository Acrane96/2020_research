# %%
from blazingsql import BlazingContext
from matplotlib import pyplot as plt
import cudf
import time
import numpy

bc_cudf = BlazingContext()
# Out:
# BlazingContext ready

# %%
# %%time
# Load CSVs into GPU DataFrames with cudf (GDF)
netflow_gdf_cudf = cudf.read_csv('./data/nf-chunk2.csv')
# Out:
# CPU times: user 3.96 s, sys: 835 ms, total: 4.8 s
# Wall time: 4.77 s

# %%
# %%time
# Create BlazingSQL table from GDF
# col_names = ['TimeSeconds','parsedDate','dateTimeStr','ipLayerProtocol','ipLayerProtocolCode','firstSeenSrcIp','firstSeenDestIp','firstSeenSrcPort','firstSeenDestPort','moreFragments','contFragments','durationSeconds','firstSeenSrcPayloadBytes','firstSeenDestPayloadBytes','firstSeenSrcTotalBytes','firstSeenDestTotalBytes','firstSeenSrcPacketCount','firstSeenDestPacketCount','recordForceOut']
# bc_cudf.create_table('netflow', '/blazingsql/2020_research/data/final.csv', delimiter='|', names=col_names)

bc_cudf.create_table('netflow', netflow_gdf_cudf)
# Out:
# CPU times: user 6.64 ms, sys: 798 µs, total: 7.44 ms
# Wall time: 6.05 ms

# %%
netflow_gdf_cudf.head()
# Out:
#     TimeSeconds           parsedDate   dateTimeStr  ipLayerProtocol  \
# 0  1.364948e+09  2013-04-03 00:11:50  2.013040e+13                6
# 1  1.364948e+09  2013-04-03 00:11:53  2.013040e+13                6
# 2  1.364948e+09  2013-04-03 00:11:54  2.013040e+13               17
# 3  1.364948e+09  2013-04-03 00:11:57  2.013040e+13                6
# 4  1.364948e+09  2013-04-03 00:12:00  2.013040e+13                6
#
#   ipLayerProtocolCode firstSeenSrcIp  firstSeenDestIp  firstSeenSrcPort  \
# 0                 TCP    10.38.37.13       172.20.0.3             42559
# 1                 TCP    10.13.77.49       172.30.0.4             42566
# 2                 UDP    172.10.0.40  172.255.255.255               138
# 3                 TCP  10.156.215.83       172.10.0.7             42593
# 4                 TCP  10.170.32.110       172.20.0.4             42612
#
#    firstSeenDestPort  moreFragments  contFragments  durationSeconds  \
# 0                 25              0              0               10
# 1                 25              0              0                9
# 2                138              0              0                0
# 3                 80              0              0                0
# 4                 80              0              0                3
#
#    firstSeenSrcPayloadBytes  firstSeenDestPayloadBytes  \
# 0                        36                        125
# 1                         0                          0
# 2                       201                          0
# 3                       170                        336
# 4                      1870                      79850
#
#    firstSeenSrcTotalBytes  firstSeenDestTotalBytes  firstSeenSrcPacketCount  \
# 0                     422                      403                        7
# 1                     186                        0                        3
# 2                     243                        0                        1
# 3                     448                      506                        5
# 4                    5730                    84250                       70
#
#    firstSeenDestPacketCount  recordForceOut
# 0                         5               0
# 1                         0               0
# 2                         0               0
# 3                         3               0
# 4                        80               0

# %%
# %%time
num_runs = 1

# make a query
queries = []
queries.append('''SELECT a.firstSeenSrcIP as source FROM netflow a''')
queries.append('''SELECT count(a.firstSeenDestPort) as targetPorts FROM netflow a''')
# queries.append('''SELECT SUM(a.firstSeenSrcTotalBytes) as bytesOut FROM netflow a''')
# queries.append('''SELECT AVG(a.firstSeenDestTotalBytes) as bytesIn FROM netflow a''')
# queries.append('''SELECT DISTINCT(a.durationSeconds) as durationSeconds FROM netflow a''')
queries.append('''SELECT MIN(parsedDate) as firstFlowDate FROM netflow a''')
queries.append('''SELECT MAX(parsedDate) as lastFlowDate FROM netflow a''')
queries.append('''SELECT COUNT(*) as attemptCount FROM netflow a''')
queries.append('''SELECT a.firstSeenSrcTotalBytes, a.firstSeenDestTotalBytes FROM netflow a ORDER BY a.firstSeenSrcTotalBytes''')
# queries.append('''SELECT netflow a.firstSeenSrcPacketCount, netflow_B a.firstSeenSrcPacketCount, netflow_B a.firstSeenDestPacketCount 
#                FROM netflow a 
#                INNER JOIN netflow_B a
#                ON (netflow a.firstSeenSrcPacketCount = netflow_B a.recordForceOut)''')

all_times=[]
for query in queries:
    times=[]
    result0 = ""
    print("\nquery:", query)
    for i in range(0,num_runs):
        print("start")
        t0 = time.time()
        result = bc_cudf.sql(query)
        t2 = time.time()
        times.append(t2 - t0)
        # result0 = result
        del result
        time.sleep(10)
        print(i+1, "query done")
    # print(result0)
    all_times.append(times)
    for j in range(0,num_runs):
        print("times[%d]:" %j + str(times[j]))
# Out:
# query: SELECT a.firstSeenSrcIP as source FROM netflow a
# start
# 1 query done
# times[0]:5.535147428512573
#
# query: SELECT count(a.firstSeenDestPort) as targetPorts FROM netflow a
# start

# %%
num_runs = 1
query = '''
        SELECT
            a.firstSeenSrcIp as source,
            a.firstSeenDestIp as destination,
            count(a.firstSeenDestPort) as targetPorts,
            SUM(a.firstSeenSrcTotalBytes) as bytesOut,
            AVG(a.firstSeenDestTotalBytes) as bytesIn,
            SUM(a.durationSeconds) as durationSeconds,
            MIN(parsedDate) as firstFlowDate,
            MAX(parsedDate) as lastFlowDate,
            COUNT(*) as attemptCount
        FROM
            netflow a
        GROUP BY
            a.firstSeenSrcIp,
            a.firstSeenDestIp
            '''

all_times=[]
times=[]
results = []
print("\nquery:", query)
for i in range(0,num_runs):
   t0 = time.time()
   # %prun result = bc_cudf.sql(query)
   t2 = time.time()
   times.append(t2 - t0)
   results.append(result)
   result0 = result
   del result
   print("trial ", i + 1, " done")
   time.sleep(1)
print(result0)
all_times.append(times)
for j in range(0,num_runs):
   print("times[%d]:" %j + str(times[j]))
# Out:
# query:
#         SELECT
#             a.firstSeenSrcIp as source,
#             a.firstSeenDestIp as destination,
#             count(a.firstSeenDestPort) as targetPorts,
#             SUM(a.firstSeenSrcTotalBytes) as bytesOut,
#             AVG(a.firstSeenDestTotalBytes) as bytesIn,
#             SUM(a.durationSeconds) as durationSeconds,
#             MIN(parsedDate) as firstFlowDate,
#             MAX(parsedDate) as lastFlowDate,
#             COUNT(*) as attemptCount
#         FROM
#             netflow a
#         GROUP BY
#             a.firstSeenSrcIp,
#             a.firstSeenDestIp
#
0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       655    0.000    0.000    0.000    0.000 generic.py:7(_check)
#        21    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#       169    0.000    0.000    0.001    0.000 base.py:75(is_dtype)
#       149    0.000    0.000    0.001    0.000 common.py:1845(_is_dtype_type)
#        42    0.000    0.000    0.001    0.000 common.py:222(asarray_tuplesafe)
#        28    0.000    0.000    0.000    0.000 dtypes.py:71(is_categorical_dtype)
#       221    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#       974    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 {built-in method NVCategory_module.n_get_values}
#        21    0.000    0.000    0.000    0.000 cast.py:1193(construct_1d_object_array_from_listlike)
#        19    0.000    0.000    0.005    0.000 dataframe.py:338(__getitem__)
#        21    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        35    0.000    0.000    0.000    0.000 series.py:90(__init__)
#       106    0.000    0.000    0.000    0.000 common.py:1702(is_extension_array_dtype)
#         9    0.000    0.000    0.000    0.000 devices.py:145(_get_or_create_context_uncached)
#       106    0.000    0.000    0.000    0.000 dtypes.py:68(find)
#         8    0.000    0.000    0.000    0.000 weakref.py:530(__init__)
#        42    0.000    0.000    0.000    0.000 dtypes.py:973(is_dtype)
#        21    0.000    0.000    0.000    0.000 base.py:504(_simple_new)
#        21    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 driver.py:290(safe_cuda_api_call)
#         9    0.000    0.000    0.000    0.000 dummyarray.py:159(__init__)
#         9    0.000    0.000    0.000    0.000 driver.py:379(__enter__)
#         9    0.000    0.000    0.000    0.000 utils.py:655(__init__)
#       107    0.000    0.000    0.000    0.000 common.py:1981(pandas_dtype)
#       136    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         9    0.000    0.000    0.001    0.000 devicearray.py:65(__init__)
#         9    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#        21    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        43    0.000    0.000    0.000    0.000 common.py:403(is_datetime64_dtype)
#         9    0.000    0.000    0.001    0.000 rmm.py:31(_array_helper)
#        21    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#     28/25    0.000    0.000    0.000    0.000 dataframe.py:332(__getattr__)
#   171/161    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        63    0.000    0.000    0.000    0.000 inference.py:253(is_list_like)
#         9    0.000    0.000    0.000    0.000 column.py:1085(build_column)
#        21    0.000    0.000    0.000    0.000 _dtype.py:319(_name_get)
#        21    0.000    0.000    0.006    0.000 dataframe.py:1105(columns)
#         4    0.000    0.000    0.001    0.000 string.py:518(indices)
#         9    0.000    0.000    0.001    0.000 dataframe.py:1501(_prepare_series_for_add)
#         4    0.000    0.000    0.000    0.000 api.py:202(_prepare_shape_strides_dtype)
#        21    0.000    0.000    0.000    0.000 dtypes.py:786(construct_from_string)
#       382    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         9    0.000    0.000    0.000    0.000 dummyarray.py:149(from_desc)
#        84    0.000    0.000    0.000    0.000 common.py:572(is_categorical_dtype)
#         4    0.000    0.000    0.001    0.000 rmm.py:167(device_array)
#         1    0.000    0.000    1.884    1.884 context.py:564(sql)
#         4    0.000    0.000    0.000    0.000 {rmm._lib.lib.rmm_alloc}
#         4    0.000    0.000    1.115    0.279 nvcategory.py:82(from_strings)
#         4    0.000    0.000    0.000    0.000 nvcategory.py:185(__init__)
#        42    0.000    0.000    0.000    0.000 dtypes.py:827(is_dtype)
#        42    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         9    0.000    0.000    0.000    0.000 buffer.py:30(__init__)
#         9    0.000    0.000    0.000    0.000 driver.py:1244(__init__)
#         9    0.000    0.000    0.001    0.000 column.py:150(from_mem_views)
#       136    0.000    0.000    0.000    0.000 abc.py:137(__instancecheck__)
#        19    0.000    0.000    0.000    0.000 series.py:216(name)
#        43    0.000    0.000    0.000    0.000 common.py:472(is_timedelta64_dtype)
#        84    0.000    0.000    0.001    0.000 common.py:536(is_interval_dtype)
#        21    0.000    0.000    0.000    0.000 common.py:1578(is_bool_dtype)
#        21    0.000    0.000    0.000    0.000 _internal.py:865(npy_ctypes_check)
#        21    0.000    0.000    0.000    0.000 numerictypes.py:365(issubdtype)
#        21    0.000    0.000    0.000    0.000 dtypes.py:929(construct_from_string)
#        42    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#        46    0.000    0.000    0.000    0.000 devicearray.py:172(device_ctypes_pointer)
#        42    0.000    0.000    0.001    0.000 common.py:1078(is_datetime64_any_dtype)
#        42    0.000    0.000    0.000    0.000 common.py:503(is_period_dtype)
#         9    0.000    0.000    0.000    0.000 dummyarray.py:169(_compute_layout)
#         9    0.000    0.000    0.000    0.000 dummyarray.py:193(_compute_extent)
#         9    0.000    0.000    0.001    0.000 dataframe.py:1566(add_column)
#       107    0.000    0.000    0.000    0.000 common.py:119(<lambda>)
#         9    0.000    0.000    0.000    0.000 dataframe.py:1443(_sanitize_values)
#         4    0.000    0.000    0.000    0.000 api.py:215(_fill_stride_by_order)
#        43    0.000    0.000    0.000    0.000 common.py:434(is_datetime64tz_dtype)
#        21    0.000    0.000    0.000    0.000 __init__.py:221(iteritems)
#        12    0.000    0.000    1.115    0.093 string.py:510(nvcategory)
#        21    0.000    0.000    0.000    0.000 dtypes.py:452(construct_from_string)
#       107    0.000    0.000    0.000    0.000 common.py:117(classes)
#         1    0.000    0.000    1.884    1.884 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 _jclass.py:206(_JClassNew)
#         1    0.000    0.000    0.000    0.000 dataframe.py:159(__init__)
#        18    0.000    0.000    0.000    0.000 dummyarray.py:109(compute_index)
#        18    0.000    0.000    0.000    0.000 dtypes.py:160(is_list_like)
#        40    0.000    0.000    0.000    0.000 base.py:475(<genexpr>)
#        21    0.000    0.000    0.000    0.000 common.py:923(is_signed_integer_dtype)
#        31    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        10    0.000    0.000    0.000    0.000 index.py:426(__init__)
#         4    0.000    0.000    0.000    0.000 string.py:445(__init__)
#        42    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        21    0.000    0.000    0.000    0.000 dtypes.py:672(construct_from_string)
#        21    0.000    0.000    0.000    0.000 common.py:1545(is_float_dtype)
#        21    0.000    0.000    0.000    0.000 common.py:1809(_get_dtype)
#        32    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55b2d6b08240}
#        16    0.000    0.000    0.000    0.000 nvstrings.py:521(size)
#        35    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         9    0.000    0.000    0.000    0.000 dataframe.py:1407(_sanitize_columns)
#        46    0.000    0.000    0.000    0.000 driver.py:1308(device_ctypes_pointer)
#        18    0.000    0.000    0.000    0.000 __init__.py:1356(debug)
#         8    0.000    0.000    0.000    0.000 series.py:238(_copy_construct)
#        16    0.000    0.000    0.000    0.000 string.py:488(__len__)
#        19    0.000    0.000    0.000    0.000 column.py:242(name)
#        45    0.000    0.000    0.000    0.000 column.py:306(__len__)
#         1    0.000    0.000    0.000    0.000 index.py:971(as_index)
#        21    0.000    0.000    0.000    0.000 common.py:980(is_unsigned_integer_dtype)
#         9    0.000    0.000    0.000    0.000 numeric.py:1782(isscalar)
#         1    0.000    0.000    0.000    0.000 _jclass.py:138(__getattribute__)
#         5    0.000    0.000    0.000    0.000 column.py:853(__init__)
#         9    0.000    0.000    0.001    0.000 devices.py:131(get_or_create_context)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         4    0.000    0.000    0.000    0.000 nvstrings.py:401(__init__)
#        21    0.000    0.000    0.000    0.000 base.py:633(_reset_identity)
#         4    0.000    0.000    0.000    0.000 driver.py:1827(memory_size_from_info)
#         1    0.000    0.000    0.000    0.000 _jstring.py:35(__new__)
#         5    0.000    0.000    0.000    0.000 numerical.py:28(__init__)
#        42    0.000    0.000    0.000    0.000 common.py:127(<lambda>)
#         9    0.000    0.000    0.001    0.000 devices.py:209(get_context)
#        21    0.000    0.000    0.000    0.000 _asarray.py:16(asarray)
#        35    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 _jobject.py:89(__init__)
#        54    0.000    0.000    0.000    0.000 column.py:238(name)
#        18    0.000    0.000    0.000    0.000 driver.py:318(_check_error)
#         9    0.000    0.000    0.000    0.000 cudautils.py:27(to_device)
#        36    0.000    0.000    0.000    0.000 dummyarray.py:110(<genexpr>)
#         1    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         6    0.000    0.000    0.000    0.000 dataframe.py:305(__setattr__)
#        16    0.000    0.000    0.000    0.000 {built-in method NVStrings_module.n_size}
#        19    0.000    0.000    0.000    0.000 dtypes.py:125(is_scalar)
#         5    0.000    0.000    0.001    0.000 rmm.py:142(device_array_from_ptr)
#         1    0.000    0.000    0.000    0.000 {method 'toString' of '_jpype.PyJPValue' objects}
#         1    0.000    0.000    0.000    0.000 _jobject.py:78(__new__)
#        26    0.000    0.000    0.000    0.000 index.py:472(__len__)
#         4    0.000    0.000    0.000    0.000 {built-in method NVCategory_module.n_size}
#        21    0.000    0.000    0.000    0.000 inference.py:121(is_iterator)
#         8    0.000    0.000    0.000    0.000 series.py:235(_copy_construct_defaults)
#         1    0.000    0.000    0.001    0.001 dataframe.py:923(__iter__)
#         1    0.000    0.000    0.000    0.000 random.py:224(_randbelow)
#        18    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#         8    0.000    0.000    0.000    0.000 series.py:319(set_index)
#         5    0.000    0.000    0.000    0.000 column.py:177(__init__)
#         9    0.000    0.000    0.000    0.000 devices.py:37(__getitem__)
#         9    0.000    0.000    0.000    0.000 driver.py:405(__exit__)
#         9    0.000    0.000    0.000    0.000 dummyarray.py:45(__init__)
#         1    0.000    0.000    0.000    0.000 index.py:1017(_setdefault_name)
#         1    0.000    0.000    0.000    0.000 base.py:1117(__iter__)
#        42    0.000    0.000    0.000    0.000 common.py:122(classes_and_not_datetimelike)
#         9    0.000    0.000    0.000    0.000 rmm.py:225(auto_device)
#        18    0.000    0.000    0.000    0.000 __init__.py:1614(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 copy.py:268(_reconstruct)
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         4    0.000    0.000    0.000    0.000 {built-in method cudf._lib.cudf.get_ctype_ptr}
#         4    0.000    0.000    0.000    0.000 {built-in method numba.mviewbuf.memoryview_get_extents_info}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.delattr}
#         1    0.000    0.000    0.000    0.000 _jobject.py:116(__str__)
#        30    0.000    0.000    0.000    0.000 column.py:859(dtype)
#         9    0.000    0.000    0.000    0.000 devices.py:77(__getattr__)
#         9    0.000    0.000    0.000    0.000 driver.py:364(get_active_context)
#         9    0.000    0.000    0.000    0.000 <string>:1(__new__)
#        18    0.000    0.000    0.000    0.000 dummyarray.py:181(is_contig)
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         1    0.000    0.000    1.884    1.884 <string>:1(<module>)
#        18    0.000    0.000    0.000    0.000 series.py:1373(index)
#         5    0.000    0.000    0.000    0.000 column.py:218(_update_null_count)
#         4    0.000    0.000    0.000    0.000 nvstrings.py:374(bind_cpointer)
#         4    0.000    0.000    0.000    0.000 nvcategory.py:207(size)
#         9    0.000    0.000    0.000    0.000 devices.py:178(_get_attached_context)
#         9    0.000    0.000    0.000    0.000 rmm.py:270(_make_finalizer)
#        18    0.000    0.000    0.000    0.000 dummyarray.py:81(get_offset)
#         9    0.000    0.000    0.000    0.000 driver.py:1773(device_memory_size)
#         9    0.000    0.000    0.000    0.000 series.py:382(__len__)
#         8    0.000    0.000    0.000    0.000 string.py:491(dtype)
#        27    0.000    0.000    0.000    0.000 dataframe.py:513(__len__)
#         4    0.000    0.000    0.000    0.000 nvcategory.py:371(values)
#         9    0.000    0.000    0.000    0.000 driver.py:516(get_primary_context)
#         9    0.000    0.000    0.000    0.000 buffer.py:203(__init__)
#         9    0.000    0.000    0.000    0.000 driver.py:1857(is_device_memory)
#        15    0.000    0.000    0.000    0.000 column.py:401(null_count)
#         1    0.000    0.000    0.000    0.000 common.py:702(is_datetimelike)
#        18    0.000    0.000    0.000    0.000 dummyarray.py:162(<genexpr>)
#         9    0.000    0.000    0.000    0.000 dummyarray.py:195(<listcomp>)
#         9    0.000    0.000    0.000    0.000 driver.py:714(prepare_for_use)
#         5    0.000    0.000    0.000    0.000 devicearray.py:439(is_c_contiguous)
#         9    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getCanonicalName' of '_jpype.PyJPClass' objects}
#        26    0.000    0.000    0.000    0.000 series.py:210(name)
#        18    0.000    0.000    0.000    0.000 {built-in method _ctypes.byref}
#        18    0.000    0.000    0.000    0.000 dummyarray.py:105(is_contiguous)
#        18    0.000    0.000    0.000    0.000 dummyarray.py:163(<genexpr>)
#         1    0.000    0.000    0.000    0.000 random.py:174(randrange)
#         1    0.000    0.000    0.000    0.000 index.py:451(copy)
#         4    0.000    0.000    0.000    0.000 base.py:3632(_values)
#         9    0.000    0.000    0.000    0.000 driver.py:409(__bool__)
#         9    0.000    0.000    0.000    0.000 buffer.py:211(ndim)
#         1    0.000    0.000    0.000    0.000 context.py:204(modifyAlgebraForDataframesWithOnlyWantedColumns)
#         9    0.000    0.000    0.000    0.000 devicearray.py:451(__len__)
#         1    0.000    0.000    0.000    0.000 random.py:218(randint)
#         5    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        21    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 string.py:495(data)
#         8    0.000    0.000    0.000    0.000 dataframe.py:1157(index)
#         5    0.000    0.000    0.000    0.000 buffer.py:189(is_contiguous)
#        15    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 dummyarray.py:228(is_c_contig)
#         1    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
#         3    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 index.py:267(rename)
#         4    0.000    0.000    0.000    0.000 string.py:500(null_count)
#         1    0.000    0.000    0.000    0.000 dataframe.py:232(_add_empty_columns)
#         4    0.000    0.000    0.000    0.000 nvcategory.py:201(get_cpointer)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 base.py:652(__len__)
#         1    0.000    0.000    0.000    0.000 context.py:567(<listcomp>)

# %%
sums = []
# for (times, query) in (all_times, queries):
for times in all_times:
    sum = 0.0
    for time_result in (times):
        sum += time_result
    print("query: " + query)
    print("총합: " + str(sum))
    print("평균: " + str(numpy.mean(times)))
    print("분산: " + str(numpy.var(times)))
    print("표준편차: " + str(numpy.std(times)))
    print("\n")
# Out:
# query:
#         SELECT
#             a.firstSeenSrcIp as source,
#             a.firstSeenDestIp as destination,
#             count(a.firstSeenDestPort) as targetPorts,
#             SUM(a.firstSeenSrcTotalBytes) as bytesOut,
#             AVG(a.firstSeenDestTotalBytes) as bytesIn,
#             SUM(a.durationSeconds) as durationSeconds,
#             MIN(parsedDate) as firstFlowDate,
#             MAX(parsedDate) as lastFlowDate,
#             COUNT(*) as attemptCount
#         FROM
#             netflow a
#         GROUP BY
#             a.firstSeenSrcIp,
#             a.firstSeenDestIp
#
# 총합: 8.67598819732666
# 평균: 0.8675988197326661
# 분산: 2.3444514944679082
# 표준편차: 1.531160179232698

# %%
gdf

# %%
# how's it look?
# df_result = cudf.DataFrame(results)
results[0].to_csv("result.csv", index=False)
